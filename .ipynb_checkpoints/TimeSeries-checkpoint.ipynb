# %%
import pandas as pd
import numpy as np

# %%
makData = pd.read_csv("preprocessed/finalDfV2.csv",
            index_col=0
           )

# %%
makData
# Out:
#                    Form ID   Index No                   NAME GENDER  \
# 0     23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1     23APF345674424112360  U1249/532             LULE ISAAC      M
# 2    23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3     23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4    23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ..                     ...        ...                    ...    ...
# 222  23APF1674647943113045  U2789/769          MAFABI  EDGAR      M
# 223  23APF1553004744147784  U0009/541     KEMIGISHA SHANITAH      F
# 224  23APF1425422752115622  U4144/507      NAKITANDWE SHARON      F
# 225  23APF1269085013144231  U0060/511  BAGAYA SHELDYNE WINYI      F
# 226   23APF192601537128082  U0083/547         CYNTHIA PRAISE      F
#
#      UACE YEAR  CODE  DISTRICT COURSE CODE  \
# 0       2022.0  42.0    MUKONO         ACC
# 1       2022.0  40.0     MPIGI         ACC
# 2       2022.0  21.0    KASESE         ACC
# 3       2022.0  33.0    MASAKA         ACC
# 4       2022.0  65.0    IBANDA         ACC
# ..         ...   ...       ...         ...
# 222     2022.0  52.0   SIRONKO         ADM
# 223     2022.0   6.0  BUSHENYI         ADM
# 224     2022.0  71.0    KALIRO         ADM
# 225     2022.0   9.0     HOIMA         ADM
# 226     2022.0  21.0    KASESE         ADM
#
#                              COURSE NAME  Total Weight
# 0                  BSC. Accounting (EVE)          42.2
# 1                  BSC. Accounting (EVE)          41.1
# 2                  BSC. Accounting (EVE)          40.6
# 3                  BSC. Accounting (EVE)          38.8
# 4                  BSC. Accounting (EVE)          38.4
# ..                                   ...           ...
# 222  Bachelor of Business Administration          42.7
# 223  Bachelor of Business Administration          42.6
# 224  Bachelor of Business Administration          42.6
# 225  Bachelor of Business Administration          42.6
# 226  Bachelor of Business Administration          42.6
#
# [226 rows x 10 columns]

# %%
# Generate a registration number for each student for identification
def getRegNo():
    studentIndice = []
    for i in range(len(makData['Index No'])):
        registrationNo = "23/U/"+ str(i+1).zfill(3)
        studentIndice.append(registrationNo)
    return list(studentIndice)

# %%
studentData = pd.DataFrame(data=getRegNo(),
                           columns=["Reg No"],
                           index=[x for x in range(len(makData["NAME"]))])

# %%
studentData['NAME'] = makData['NAME']

# %%
studentData['COURSE'] = makData['COURSE NAME']

# %%
studentData.head()
# Out:
#      Reg No                  NAME                 COURSE
# 0  23/U/001  LUKABWE DOUGLAS MARK  BSC. Accounting (EVE)
# 1  23/U/002            LULE ISAAC  BSC. Accounting (EVE)
# 2  23/U/003   HAULAH SULAIT BIIRA  BSC. Accounting (EVE)
# 3  23/U/004      NAMBALYE EVELYNE  BSC. Accounting (EVE)
# 4  23/U/005       KEMIGISHA RUSIA  BSC. Accounting (EVE)

# %%
import random
random.choice(makData['NAME'])
# Out:
# 'MUKISA PAUL'

# %%
# Financial Data
payments = pd.DataFrame(data=getRegNo(),
                    columns=["Reg No"],
                       index=[x for x in range(len(makData["NAME"]))])

# %%
payments
# Out:
#        Reg No
# 0    23/U/001
# 1    23/U/002
# 2    23/U/003
# 3    23/U/004
# 4    23/U/005
# ..        ...
# 221  23/U/222
# 222  23/U/223
# 223  23/U/224
# 224  23/U/225
# 225  23/U/226
#
# [226 rows x 1 columns]

# %%
import random
randrange(1, 6000, 1) * 1000
# Out:
# 4035000

# %%
len([random.choice(list(studentData['Reg No'])) for x in range(len(dates))])
# Out:
# 21024

# %%
# Tuition paid over a period of a baseline frequency of 60 minutes
dates = pd.date_range("2023-08-01 00:00:00",
                      "2023-12-24 23:59:00",
                     freq="60min")

# %%
fndf = pd.DataFrame(
                    {"Reg No": 
    [random.choice(list(studentData['Reg No'][::10])) for x in range(len(dates))],
                        "Tuition": 
    [random.randint(1, 6000) * 1000 for x in range(len(dates))]

                    },
                     index=[random.choice(dates) for x in range(len(dates))]
                   )

# %%
fndf
# Out:
#                        Reg No  Tuition
# 2023-10-23 11:00:00  23/U/071  5293000
# 2023-12-20 20:00:00  23/U/121   310000
# 2023-11-28 08:00:00  23/U/041  4924000
# 2023-08-02 18:00:00  23/U/191  4228000
# 2023-09-02 15:00:00  23/U/221  3997000
# ...                       ...      ...
# 2023-10-01 07:00:00  23/U/041  4108000
# 2023-09-18 13:00:00  23/U/191   211000
# 2023-09-09 03:00:00  23/U/001  4971000
# 2023-12-24 17:00:00  23/U/201  4876000
# 2023-09-25 13:00:00  23/U/191  2449000
#
# [3504 rows x 2 columns]

# %%
fndf.groupby(["Reg No"],
#              as_index=False
            ).sum().head(60)
# Out:
#             Tuition
# Reg No
# 23/U/001  508555000
# 23/U/011  406833000
# 23/U/021  393076000
# 23/U/031  488993000
# 23/U/041  477162000
# 23/U/051  470207000
# 23/U/061  453786000
# 23/U/071  477883000
# 23/U/081  506427000
# 23/U/091  468008000
# 23/U/101  489794000
# 23/U/111  458492000
# 23/U/121  430589000
# 23/U/131  470012000
# 23/U/141  421886000
# 23/U/151  379788000
# 23/U/161  445257000
# 23/U/171  437763000
# 23/U/181  465735000
# 23/U/191  507545000
# 23/U/201  512693000
# 23/U/211  466879000
# 23/U/221  434586000

# %%
fndf.head(30)
# Out:
#                        Reg No  Tuition
# 2023-10-23 11:00:00  23/U/071  5293000
# 2023-12-20 20:00:00  23/U/121   310000
# 2023-11-28 08:00:00  23/U/041  4924000
# 2023-08-02 18:00:00  23/U/191  4228000
# 2023-09-02 15:00:00  23/U/221  3997000
# 2023-12-16 18:00:00  23/U/131  5548000
# 2023-12-12 06:00:00  23/U/181  3621000
# 2023-09-03 10:00:00  23/U/131  4851000
# 2023-08-14 01:00:00  23/U/131  2073000
# 2023-08-03 01:00:00  23/U/021  5831000
# 2023-10-19 00:00:00  23/U/051  5468000
# 2023-12-10 15:00:00  23/U/011  3018000
# 2023-09-22 00:00:00  23/U/121  1929000
# 2023-09-26 23:00:00  23/U/041  4147000
# 2023-11-22 02:00:00  23/U/001  2736000
# 2023-11-13 20:00:00  23/U/191   687000
# 2023-11-29 23:00:00  23/U/001  2214000
# 2023-10-22 11:00:00  23/U/021   178000
# 2023-08-29 20:00:00  23/U/091  3398000
# 2023-08-27 20:00:00  23/U/041  1555000
