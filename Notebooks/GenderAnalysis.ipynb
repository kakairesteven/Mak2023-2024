# %% [markdown]
# <h2>
#     Imports
# </h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../Data/Private2.csv',
                 index_col=0,
                )

# %%
df
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                   NAME  \
# 0       23APF412304454141015        U0391  U0391/673   LUKABWE DOUGLAS MARK
# 1       23APF345674424112360        U1249  U1249/532             LULE ISAAC
# 2      23APF1361730063122187        U0459  U0459/676    HAULAH SULAIT BIIRA
# 3       23APF519647933132646        U1611  U1611/887       NAMBALYE EVELYNE
# 4      23APF1481620160129238        U0083  U0083/555        KEMIGISHA RUSIA
# ...                      ...          ...        ...                    ...
# 14910   23APF727648568141557        U0017  U0017/548  KIZZA VANESSA ITRONCE
# 14911   23APF963075058135059        U0033  U0033/581            OTIM DANIEL
# 14912  23APF1618205309130850        U0077  U0077/736          MUKETI  JOVIA
# 14913   23APF575513287117711        U0077  U0077/564           AWOR REBECCA
# 14914  23APF1477867021106233        U0017  U0017/606  SAGATI LETICIA OKURUT
#
# ...

# %%
df = df.drop(['INDEX NO', 'NAME', 'SCHOOL INDEX'], axis=1)

# %%
df.astype({'UACE YEAR':'int64',
          'CODE': 'int64'
          })
# Out:
#               APPLICATION NO GENDER  UACE YEAR  CODE DISTRICT COURSE CODE  \
# 0       23APF412304454141015      M       2022    42   MUKONO         ACC
# 1       23APF345674424112360      M       2022    40    MPIGI         ACC
# 2      23APF1361730063122187      F       2022    21   KASESE         ACC
# 3       23APF519647933132646      F       2022    33   MASAKA         ACC
# 4      23APF1481620160129238      F       2022    65   IBANDA         ACC
# ...                      ...    ...        ...   ...      ...         ...
# 14910   23APF727648568141557      F       2022    17   KAMULI         VET
# 14911   23APF963075058135059      M       2022    31     LIRA         VET
# 14912  23APF1618205309130850      F       2022    74  MARACHA         VET
# 14913   23APF575513287117711      F       2022    31     LIRA         VET
# 14914  23APF1477867021106233      F       2022    48  PALLISA         VET
#
#                   COURSE NAME  TOTAL WEIGHT WEIGHT RANGE  \
# ...

# %%
df.to_csv('../Data/finalDf.csv')

# %%
df.groupby(['COURSE CODE', 'GENDER'])['APPLICATION NO'].count().head(200
                                                                    )
# Out:
# COURSE CODE  GENDER
# ACC          F          62
#              M          86
# ADJ          F          19
#              M          11
# ADM          F         127
#                       ...
# COX          F          53
#              M          66
# CRJ          F          10
#              M          10
# CRO          F          10
# Name: APPLICATION NO, Length: 200, dtype: int64

# %%
df[df['COURSE CODE'][0] == 'A']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Novel\Data\Python\DataAnalysis\DataAnalysisVenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df[df['COURSE CODE'][0] == 'A']
#
# ...

# %%
# plt.xticks(
#     rotation=90,
# );
plt.figure(
    figsize=(200,200),
);
sns.catplot(
    data=df[df['COURSE CODE'][0] == 'A'],
    x="COURSE CODE",
    # y="WEIGHT RANGE",
    hue="GENDER",
    kind="count"
);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Novel\Data\Python\DataAnalysis\DataAnalysisVenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 8
#       1 # plt.xticks(
# ...
