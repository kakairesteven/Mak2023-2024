# %%
from customFunctions import readSavedData
import pandas as pd
import numpy as np
import yaml
import csv
import seaborn as sns

# %%
with open('../Notebooks/preprocessingConfig.yml', 'r') as file:
    config = yaml.safe_load(file)

# %%
filename = config['general']['saved_file']

# %%
df = pd.read_csv('../Data/Private.csv',
                 # index_col=False,
                )

# %%
df17 = pd.read_csv("../Data/PrivateAdmissions20172018.csv",
                  )

# %%
# Sort by Total weight
df.sort_values(by=['TOTAL WEIGHT'],
                    ignore_index=True,
                    ascending=True,
                    kind='mergesort',
                   )
# Get School index
def getSchoolIndex(StudentIndex):
    schoolIndex = StudentIndex[:5]
    return schoolIndex

# Get admissions by District
def getAdmissionsByDistrict(df, district):
    district = district.upper()
    df = df[df.DISTRICT == district]
    return df

def getAdmissionsByProgramCode(df, code):
    code = code.upper()
    df = df[df['COURSE CODE'] == code]
    return df

def getAdmissionsBySchoolIndex(df, schoolIndex):
    schoolIndex = schoolIndex.upper()
    df = df[df['SCHOOL INDEX'] == schoolIndex]
    return df

# %%
df.drop(columns=['NAME', 'INDEX NO'])
# Out:
#               APPLICATION NO GENDER  UACE YEAR  CODE DISTRICT COURSE CODE  \
# 0       23APF412304454141015      M     2022.0  42.0   MUKONO         ACC
# 1       23APF345674424112360      M     2022.0  40.0    MPIGI         ACC
# 2      23APF1361730063122187      F     2022.0  21.0   KASESE         ACC
# 3       23APF519647933132646      F     2022.0  33.0   MASAKA         ACC
# 4      23APF1481620160129238      F     2022.0  65.0   IBANDA         ACC
# ...                      ...    ...        ...   ...      ...         ...
# 14910   23APF727648568141557      F     2022.0  17.0   KAMULI         VET
# 14911   23APF963075058135059      M     2022.0  31.0     LIRA         VET
# 14912  23APF1618205309130850      F     2022.0  74.0  MARACHA         VET
# 14913   23APF575513287117711      F     2022.0  31.0     LIRA         VET
# 14914  23APF1477867021106233      F     2022.0  48.0  PALLISA         VET
#
#                   COURSE NAME  TOTAL WEIGHT
# 0       BSC. Accounting (EVE)          42.2
# 1       BSC. Accounting (EVE)          41.1
# 2       BSC. Accounting (EVE)          40.6
# 3       BSC. Accounting (EVE)          38.8
# 4       BSC. Accounting (EVE)          38.4
# ...                       ...           ...
# 14910  B. Veterinary Medicine          41.8
# 14911  B. Veterinary Medicine          41.7
# 14912  B. Veterinary Medicine          41.6
# 14913  B. Veterinary Medicine          40.4
# 14914  B. Veterinary Medicine          40.1
#
# [14915 rows x 8 columns]

# %%
df
# Out:
#               APPLICATION NO   INDEX NO                   NAME GENDER  \
# 0       23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1       23APF345674424112360  U1249/532             LULE ISAAC      M
# 2      23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3       23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4      23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ...                      ...        ...                    ...    ...
# 14910   23APF727648568141557  U0017/548  KIZZA VANESSA ITRONCE      F
# 14911   23APF963075058135059  U0033/581            OTIM DANIEL      M
# 14912  23APF1618205309130850  U0077/736          MUKETI  JOVIA      F
# 14913   23APF575513287117711  U0077/564           AWOR REBECCA      F
# 14914  23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F
#
#        UACE YEAR  CODE DISTRICT COURSE CODE             COURSE NAME  \
# 0         2022.0  42.0   MUKONO         ACC   BSC. Accounting (EVE)
# 1         2022.0  40.0    MPIGI         ACC   BSC. Accounting (EVE)
# 2         2022.0  21.0   KASESE         ACC   BSC. Accounting (EVE)
# 3         2022.0  33.0   MASAKA         ACC   BSC. Accounting (EVE)
# 4         2022.0  65.0   IBANDA         ACC   BSC. Accounting (EVE)
# ...          ...   ...      ...         ...                     ...
# 14910     2022.0  17.0   KAMULI         VET  B. Veterinary Medicine
# 14911     2022.0  31.0     LIRA         VET  B. Veterinary Medicine
# 14912     2022.0  74.0  MARACHA         VET  B. Veterinary Medicine
# 14913     2022.0  31.0     LIRA         VET  B. Veterinary Medicine
# 14914     2022.0  48.0  PALLISA         VET  B. Veterinary Medicine
#
#        TOTAL WEIGHT
# 0              42.2
# 1              41.1
# 2              40.6
# 3              38.8
# 4              38.4
# ...             ...
# 14910          41.8
# 14911          41.7
# 14912          41.6
# 14913          40.4
# 14914          40.1
#
# [14915 rows x 10 columns]

# %%
# sort by course
df.sort_values(by=['COURSE CODE'],
               kind='mergesort',
               ascending=True,
               ignore_index=True,
              ).head(50)
# Out:
#            APPLICATION NO   INDEX NO                       NAME GENDER  \
# 0    23APF412304454141015  U0391/673       LUKABWE DOUGLAS MARK      M
# 1    23APF345674424112360  U1249/532                 LULE ISAAC      M
# 2   23APF1361730063122187  U0459/676        HAULAH SULAIT BIIRA      F
# 3    23APF519647933132646  U1611/887           NAMBALYE EVELYNE      F
# 4   23APF1481620160129238  U0083/555            KEMIGISHA RUSIA      F
# 5   23APF1501202078128326  U2373/501               LUWAGA TONNY      M
# 6   23APF1139056282132364  U0856/511          NAMAGEMBE MARTINA      F
# 7    23APF101396019107326  U2929/521              KALUNGI TITUS      M
# 8    23APF515017899120808  U1609/550             KIZITO PATRICK      M
# 9   23APF1672224247102423  U1224/882      NDYOMUHIRWA CHRISTIAN      M
# 10   23APF202185286140690  U1350/503            GWOKYALYA RESTY      F
# 11   23APF231194390150185  U0086/599              WAISWA CEASER      M
# 12   23APF174935849136324  U0923/523           NABUUMA MAJOREEN      F
# 13   23APF324272143128932  U2789/821               TAMALE COLIN      M
# 14   23APF231927019128941  U0960/506              LUUTU DOUGLAS      M
# 15  23APF1362423415106885  U0459/684     KASANGAKI MARIAM BINTA      F
# 16  23APF1368966146127414  U1611/947            NANSUBUGA LYDIA      F
# 17  23APF1031507983139846  U3219/507           NANDAGIRE SCOVIA      F
# 18   23APF980625096133316  U0737/531          MUDOBYA CHRISTINE      F
# 19   23APF154566486115108  U0036/560              ASHABA PERUTH      F
# 20   23APF283201719136962  U1979/584     MIREMBE SHALOM NAMYALO      F
# 21   23APF957749380107698  U2381/539             KISEMBO ELIJAH      M
# 22  23APF1091499022125514  U0200/522        LUYIGA T. CATHERINE      F
# 23  23APF1158623449102037  U3082/603             MUGISA DERRICK      M
# 24  23APF1057280688118519  U0027/750              WANGOTA BRIAN      M
# 25   23APF104197063663745  U2789/553     MWEBESA SOLOMON ARTHUR      M
# 26    23APF16043054134531  U2474/892              MUHAIRWE JOEL      M
# 27   23APF436324879132722  U2839/522         TUMUSIIME PATRICIA      F
# 28  23APF1080023620127280  U2144/516           KABARUNGI EMILLY      F
# 29   23APF157015655125355  U1542/582               WAKIBUGO IAN      M
# 30   23APF141959743797295  U1451/517               NAIGAMBI ALI      M
# 31   23APF751191108106210  U2789/560            NALWEYISO DAISY      F
# 32   23APF724414868141141  U3219/508              NAMBAYO KATHY      F
# 33  23APF1413319323135980  U1969/524            KAKOOZA MOHMMAD      M
# 34   23APF593373474116716  U0859/554    KIVEBULAAYA LIVINGSTONE      M
# 35    23APF75774350148691  U0459/630      KIJJIDE AFIZI MUHAMAD      M
# 36   23APF238774767111982  U2962/615      BALYOKWAIBWE EMMANUEL      M
# 37   23APF785739568144218  U0760/553            SUNDAY EMMANUEL      M
# 38   23APF269087811114307  U3941/514    LUKYAMUZI JUDE THADDEUS      M
# 39   23APF810803954100945  U0053/824             ATEGEKA ROBERT      M
# 40    23APF69842964149134  U0065/671  KAWUNGEZI MWESIGWA SIMEON      M
# 41  23APF1094990594129842  U0194/504               BBUMBA CYRUS      M
# 42   23APF271115874132692  U1879/641           NAKIYEMBA PHIONA      F
# 43    23APF74069275788805  U0053/898    NSARASHA GEORGE SPENCER      M
# 44   23APF935474430128208  U1542/574     NALUMANSI PATIENCE .D.      F
# 45  23APF1496502224140063  U0052/570               KATO MATSIKO      M
# 46   23APF602826709105772  U2431/568                  MALE JOHN      M
# 47   23APF566135453148449  U0645/531             NANTALE ESTHER      F
# 48  23APF1518329823115184  U0050/620        AWYAT MONICA GLORIA      F
# 49    23APF58408276899076  U2338/611            KAYONGO PATRICK      M
#
#     UACE YEAR   CODE    DISTRICT COURSE CODE            COURSE NAME  \
# 0      2022.0   42.0      MUKONO         ACC  BSC. Accounting (EVE)
# 1      2022.0   40.0       MPIGI         ACC  BSC. Accounting (EVE)
# 2      2022.0   21.0      KASESE         ACC  BSC. Accounting (EVE)
# 3      2022.0   33.0      MASAKA         ACC  BSC. Accounting (EVE)
# 4      2022.0   65.0      IBANDA         ACC  BSC. Accounting (EVE)
# 5      2018.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 6      2022.0   25.0      KIBOGA         ACC  BSC. Accounting (EVE)
# 7      2022.0   75.0     MITYANA         ACC  BSC. Accounting (EVE)
# 8      2011.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
# 9      2022.0   50.0   RUKUNGIRI         ACC  BSC. Accounting (EVE)
# 10     2022.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
# 11     2009.0   17.0      KAMULI         ACC  BSC. Accounting (EVE)
# 12     2017.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 13     2022.0   91.0       GOMBA         ACC  BSC. Accounting (EVE)
# 14     2022.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
# 15     2022.0   13.0    KABAROLE         ACC  BSC. Accounting (EVE)
# 16     2022.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
# 17     2022.0   49.0       RAKAI         ACC  BSC. Accounting (EVE)
# 18     2007.0   10.0      IGANGA         ACC  BSC. Accounting (EVE)
# 19     2020.0  101.0      LWENGO         ACC  BSC. Accounting (EVE)
# 20     2022.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 21     2022.0    9.0       HOIMA         ACC  BSC. Accounting (EVE)
# 22     2022.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 23     2022.0  102.0      KAGADI         ACC  BSC. Accounting (EVE)
# 24     2022.0   11.0       JINJA         ACC  BSC. Accounting (EVE)
# 25     2013.0   30.0    KYENJOJO         ACC  BSC. Accounting (EVE)
# 26     2022.0  118.0  BUNYANGABU         ACC  BSC. Accounting (EVE)
# 27     2022.0    9.0       HOIMA         ACC  BSC. Accounting (EVE)
# 28     2022.0   18.0    KAMWENGE         ACC  BSC. Accounting (EVE)
# 29     2022.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 30     2020.0   11.0       JINJA         ACC  BSC. Accounting (EVE)
# 31     2022.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
# 32     2022.0   77.0      BUDAKA         ACC  BSC. Accounting (EVE)
# 33     2022.0   88.0   BUTAMBALA         ACC  BSC. Accounting (EVE)
# 34     2022.0   41.0     MUBENDE         ACC  BSC. Accounting (EVE)
# 35     2022.0   88.0   BUTAMBALA         ACC  BSC. Accounting (EVE)
# 36     2022.0   90.0     BUYENDE         ACC  BSC. Accounting (EVE)
# 37     2022.0   18.0    KAMWENGE         ACC  BSC. Accounting (EVE)
# 38     2022.0   33.0      MASAKA         ACC  BSC. Accounting (EVE)
# 39     2009.0    9.0       HOIMA         ACC  BSC. Accounting (EVE)
# 40     2022.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
# 41     2022.0   42.0      MUKONO         ACC  BSC. Accounting (EVE)
# 42     2022.0   10.0      IGANGA         ACC  BSC. Accounting (EVE)
# 43     2018.0   12.0      KABALE         ACC  BSC. Accounting (EVE)
# 44     2022.0   32.0     LUWEERO         ACC  BSC. Accounting (EVE)
# 45     2022.0    6.0    BUSHENYI         ACC  BSC. Accounting (EVE)
# 46     2022.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 47     2022.0   55.0      WAKISO         ACC  BSC. Accounting (EVE)
# 48     2022.0   54.0      TORORO         ACC  BSC. Accounting (EVE)
# 49     2022.0   16.0     KAMPALA         ACC  BSC. Accounting (EVE)
#
#     TOTAL WEIGHT
# 0           42.2
# 1           41.1
# 2           40.6
# 3           38.8
# 4           38.4
# 5           38.4
# 6           38.2
# 7           38.1
# 8           37.9
# 9           37.9
# 10          37.8
# 11          37.0
# 12          36.5
# 13          35.8
# 14          35.8
# 15          35.5
# 16          35.3
# 17          34.6
# 18          34.6
# 19          34.4
# 20          34.3
# 21          34.1
# 22          33.8
# 23          33.5
# 24          33.3
# 25          33.0
# 26          32.8
# 27          32.5
# 28          32.4
# 29          32.0
# 30          31.5
# 31          31.4
# 32          31.3
# 33          31.2
# 34          31.1
# 35          31.1
# 36          31.1
# 37          31.0
# 38          31.0
# 39          30.9
# 40          30.4
# 41          30.4
# 42          30.3
# 43          30.2
# 44          30.2
# 45          30.1
# 46          29.5
# 47          29.5
# 48          29.3
# 49          29.1

# %%
df17SchoolIndices = df17['INDEX NO'].apply(getSchoolIndex)

# %%
indices = df17SchoolIndices.tolist()

# %%
schools = df17['SCHOOL'].tolist()

# %%
schoolsDf = pd.DataFrame([],
                          columns=['School Index', 'School Name'],
)

# %%
schoolsDf['School Index'] = indices

# %%
schoolsDf['School Name'] = schools

# %%
schoolsDf = schoolsDf.drop_duplicates(['School Index'])

# %%
schoolsDf = schoolsDf.sort_values(by='School Index', ascending=True, ignore_index=True)

# %%
schoolsDf = schoolsDf[schoolsDf['School Index'] != 'NO']

# %%
schoolDict = {schoolsDf['School Index'].tolist()[x]:schoolsDf['School Name'].tolist()[x] for x in range(len(schoolsDf))}

# %%
# schoolDict

# %%
# Add school index to df
df.insert(1, "SCHOOL INDEX", df['INDEX NO'].apply(getSchoolIndex))

# %%
# Students from a school with School Index U0078'. This is Iganga High School: U0078, 
df[df['SCHOOL INDEX'] == 'U0017'].sort_values(by="TOTAL WEIGHT", ascending=False)
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO  \
# 14119  23APF1431768274140888        U0017  U0017/637
# 14137    23APF59554089107243        U0017  U0017/546
# 3866    23APF950938163143107        U0017  U0017/678
# 12447   23APF235352693145115        U0017  U0017/654
# 3867   23APF1430543958148268        U0017  U0017/620
# ...                      ...          ...        ...
# 5932    23APF383732361142513        U0017  U0017/584
# 10018    23APF66985098145287        U0017  U0017/624
# 5904    23APF246648230138606        U0017  U0017/670
# 10039     23APF7902698130457        U0017  U0017/676
# 10242   23APF738022091113672        U0017  U0017/652
#
#                             NAME GENDER  UACE YEAR   CODE   DISTRICT  \
# 14119           IKIRING PATRICIA      F     2022.0   29.0       KUMI
# 14137               KIRABO DENIZ      F     2022.0    4.0     BUGIRI
# 3866      WANGUBO MAIMUNA MUTESI      F     2022.0   55.0     WAKISO
# 12447        NABIRYE RESTY TINAH      F     2022.0  100.0      LUUKA
# 3867                AKULLU SARAH      F     2022.0   76.0       OYAM
# ...                          ...    ...        ...    ...        ...
# 5932   NAMAGANDA   PERSIS  SARAH      F     2022.0   79.0  NAMUTUMBA
# 10018            AMULEN  CYNTHIA      F     2022.0   67.0    BUKEDEA
# 5904           NANTAMBI VICTORIA      F     2022.0    4.0     BUGIRI
# 10039        WAMBUYA ESTHER CARO      F     2022.0   36.0      MBALE
# 10242           MWEBAZA CAROLINE      F     2022.0   12.0     KABALE
#
#       COURSE CODE                          COURSE NAME  TOTAL WEIGHT
# 14119         SOW              BACHELOR OF SOCIAL WORK          49.6
# 14137         SQS               BSC Quantity Surveying          48.8
# 3866          BCA  BACHELOR OF CHINESE & ASIAN STUDIES          48.4
# 12447         IST  B. INFORMATION SYSTEMS & TECHNOLOGY          47.2
# 3867          BCA  BACHELOR OF CHINESE & ASIAN STUDIES          47.2
# ...           ...                                  ...           ...
# 5932          BJS         BSC. ACCOUNTING, JINJA (DAY)          22.6
# 10018         COB                    B. COMMERCE (EVE)          18.2
# 5904          BJO             B. COMMERCE, JINJA (DAY)          17.7
# 10039         COB                    B. COMMERCE (EVE)          16.5
# 10242         COJ                   B.Commerce (Jinja)          13.3
#
# [70 rows x 11 columns]

# %%
df['SCHOOL'] = df['SCHOOL INDEX'].map(schoolDict)

# %%
df.to_csv('../Data/Private2022.csv',
          index=False,
         )

# %%
df2 = pd.read_csv('../Data/Private2022.csv', 
                  # index_col=False,
                 )

# %%
df2
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                   NAME  \
# 0       23APF412304454141015        U0391  U0391/673   LUKABWE DOUGLAS MARK
# 1       23APF345674424112360        U1249  U1249/532             LULE ISAAC
# 2      23APF1361730063122187        U0459  U0459/676    HAULAH SULAIT BIIRA
# 3       23APF519647933132646        U1611  U1611/887       NAMBALYE EVELYNE
# 4      23APF1481620160129238        U0083  U0083/555        KEMIGISHA RUSIA
# ...                      ...          ...        ...                    ...
# 14910   23APF727648568141557        U0017  U0017/548  KIZZA VANESSA ITRONCE
# 14911   23APF963075058135059        U0033  U0033/581            OTIM DANIEL
# 14912  23APF1618205309130850        U0077  U0077/736          MUKETI  JOVIA
# 14913   23APF575513287117711        U0077  U0077/564           AWOR REBECCA
# 14914  23APF1477867021106233        U0017  U0017/606  SAGATI LETICIA OKURUT
#
#       GENDER  UACE YEAR  CODE DISTRICT COURSE CODE             COURSE NAME  \
# 0          M     2022.0  42.0   MUKONO         ACC   BSC. Accounting (EVE)
# 1          M     2022.0  40.0    MPIGI         ACC   BSC. Accounting (EVE)
# 2          F     2022.0  21.0   KASESE         ACC   BSC. Accounting (EVE)
# 3          F     2022.0  33.0   MASAKA         ACC   BSC. Accounting (EVE)
# 4          F     2022.0  65.0   IBANDA         ACC   BSC. Accounting (EVE)
# ...      ...        ...   ...      ...         ...                     ...
# 14910      F     2022.0  17.0   KAMULI         VET  B. Veterinary Medicine
# 14911      M     2022.0  31.0     LIRA         VET  B. Veterinary Medicine
# 14912      F     2022.0  74.0  MARACHA         VET  B. Veterinary Medicine
# 14913      F     2022.0  31.0     LIRA         VET  B. Veterinary Medicine
# 14914      F     2022.0  48.0  PALLISA         VET  B. Veterinary Medicine
#
#        TOTAL WEIGHT                           SCHOOL
# 0              42.2       ST.JOSEPH'S S S, NAGGALAMA
# 1              41.1              KINAAWA HIGH SCHOOL
# 2              40.6                KAWEMPE MUSLIM SS
# 3              38.8  OURLADY OF AFRICA SS NAMILYANGO
# 4              38.4    IMMACULATE HEART GIRLS SCHOOL
# ...             ...                              ...
# 14910          41.8          IGANGA SECONDARY SCHOOL
# 14911          41.7        ST MARY'S COLLEGE, KISUBI
# 14912          41.6           GOMBE SECONDARY SCHOOL
# 14913          40.4           GOMBE SECONDARY SCHOOL
# 14914          40.1          IGANGA SECONDARY SCHOOL
#
# [14915 rows x 12 columns]

# %%
# No duplicates
df[df["APPLICATION NO"].duplicated()].value_counts()
# Out:
# APPLICATION NO        SCHOOL INDEX  INDEX NO   NAME            GENDER  UACE YEAR  CODE  DISTRICT  COURSE CODE  COURSE NAME                TOTAL WEIGHT  SCHOOL
# 23APF992513978128612  U0178         U0178/548  NAHWERA DOREEN  F       2022.0     18.0  KAMWENGE  LIS          B.Library & Infor.Science  29.2          CALTEC ACADEMY, MAKERERE    1
# Name: count, dtype: int64

# %%
# Students admitted to two courses
df[df['INDEX NO'] == 'U0178/548']
# Out:
#              APPLICATION NO SCHOOL INDEX   INDEX NO            NAME GENDER  \
# 11743  23APF992513978128612        U0178  U0178/548  NAHWERA DOREEN      F
# 12766  23APF992513978128612        U0178  U0178/548  NAHWERA DOREEN      F
#
#        UACE YEAR  CODE  DISTRICT COURSE CODE                      COURSE NAME  \
# 11743     2022.0  18.0  KAMWENGE         EDA  Bachelor of Arts with Education
# 12766     2022.0  18.0  KAMWENGE         LIS        B.Library & Infor.Science
#
#        TOTAL WEIGHT                    SCHOOL
# 11743          29.2  CALTEC ACADEMY, MAKERERE
# 12766          29.2  CALTEC ACADEMY, MAKERERE

# %%
# Describe data 
df.describe()
# Out:
#           UACE YEAR          CODE  TOTAL WEIGHT
# count  14915.000000  14915.000000  14915.000000
# mean    2021.574187     46.417499     31.401495
# std        1.911034     30.508257      7.820673
# min     1995.000000      1.000000      8.900000
# 25%     2022.000000     18.000000     25.700000
# 50%     2022.000000     42.000000     31.300000
# 75%     2022.000000     65.000000     37.100000
# max     2022.000000    123.000000     53.900000

# %%
dfdesc = df.describe()

# %%
AverageWt = dfdesc.loc['mean']['TOTAL WEIGHT']

# %%
AverageWt
# Out:
# 31.40149513912169

# %%
# Admissions with min UACE year
df[df['UACE YEAR'] == df['UACE YEAR'].min()]
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                  NAME  \
# 1916   23APF1071633136149141        U0055  U0055/582         KIYEMBA HENRY
# 12650     23APF5536474177057        U0212  U0212/870  NABULINDO JANE KWOBA
#
#       GENDER  UACE YEAR  CODE DISTRICT COURSE CODE  \
# 1916       M     1995.0  42.0   MUKONO         BBA
# 12650      F     1995.0   7.0    BUSIA         LGM
#
#                                      COURSE NAME  TOTAL WEIGHT  \
# 1916   Bachelor of Business Administration (EVE)          25.9
# 12650          B.Leadership and Governance (EVE)          17.4
#
#                              SCHOOL
# 1916   BISHOP'S SEC. SCHOOL, MUKONO
# 12650                           NaN

# %%
# Unique admission years
df['UACE YEAR'].unique()
# Out:
# array([2022., 2018., 2011., 2009., 2017., 2007., 2020., 2013., 2019.,
#        2015., 2016., 2008., 2012., 2010., 2003., 2014., 2006., 1996.,
# 12331             ABEJA CAROLINE      F     2022.0   31.0      LIRA
# 12436         APIO FELLINE OLANG      F     2022.0   82.0  ALEBTONG
# 13679            APIO LUCKY RUTH      F     2022.0   31.0      LIRA
# 14063              OJOK EMMANUEL      M     2022.0   31.0      LIRA
# 14551           OKULLO ALEXANDER      M     2022.0   31.0      LIRA
# 14901    ATYANG JONATHAN JOHNSON      M     2022.0   31.0      LIRA
# 14907         AYOTO GLORIA MERCY      F     2022.0   59.0  AMOLATAR
#
#       COURSE CODE                                        COURSE NAME  \
# 942           ASE                           BA(Social Sciences)(EVE)
# 974           ASE                           BA(Social Sciences)(EVE)
# 1008          ASE                           BA(Social Sciences)(EVE)
# 1477          BAP                          B. Animal Produ.Techn Mgt
# 3215          BBD                Bachelor of Business Administration
# 3830          BBT               Bachelor of Science in Biotechnology
# 3877          BCA                BACHELOR OF CHINESE & ASIAN STUDIES
# 3935          BCB                         BSC (Conservation Biology)
# 4324          BEN                       Bachelor of Entrepreneurship
# 4451          BEN                       Bachelor of Entrepreneurship
# 4521          BFA                               Bachelor of Fine Art
# 4811          BHM                        B.Human Resource Management
# 4975          BHM                        B.Human Resource Management
# 5053          BHM                        B.Human Resource Management
# 5140          BIB                          B. International Business
# 5459          BIB                          B. International Business
# 5822          BJB                 B. BUSINESS COMPUTING, JINJA (EVE)
# 5884          BJO                           B. COMMERCE, JINJA (DAY)
# 6661          BMS                              Bachelor of Marketing
# 7246          BQE                  Bachelor (Quantitative Economics)
# 7298          BQE                  Bachelor (Quantitative Economics)
# 7311          BRJ  Bachelor of Business Administration(Jinja) (MUBS)
# 8812          BTT                    B.Travel and Tourism Management
# 8839          BTT                    B.Travel and Tourism Management
# 9273          BUS                              B.Business Statistics
# 10273         COM                               Bachelor of Commerce
# 10488         COM                               Bachelor of Commerce
# 10489         COM                               Bachelor of Commerce
# 11013         ECE                                 BA(Economics)(EVE)
# 11334         EDA                    Bachelor of Arts with Education
# 11459         EDA                    Bachelor of Arts with Education
# 11517         EDA                    Bachelor of Arts with Education
# 12319         FST                      BSC Food Science & Technology
# 12331         FST                      BSC Food Science & Technology
# 12436         HUN             Bachelor of Science in Human Nutrition
# 13679         PSM                B. Procurement and Supply Chain Mgt
# 14063         SEC                  Bachelor of Science  (Economics )
# 14551         TLM         B.Transport and Logistics Management (EVE)
# 14901         VET                             B. Veterinary Medicine
# 14907         VET                             B. Veterinary Medicine
#
#        TOTAL WEIGHT SCHOOL
# 942            36.4    NaN
# 974            34.1    NaN
# 1008           33.1    NaN
# 1477           21.3    NaN
# 3215           28.8    NaN
# 3830           34.7    NaN
# 3877           35.1    NaN
# 3935           17.8    NaN
# 4324           34.7    NaN
# 4451           23.9    NaN
# 4521           31.1    NaN
# 4811           39.4    NaN
# 4975           32.7    NaN
# 5053           30.8    NaN
# 5140           40.7    NaN
# 5459           26.0    NaN
# 5822           20.6    NaN
# 5884           29.2    NaN
# 6661           32.3    NaN
# 7246           35.9    NaN
# 7298           33.8    NaN
# 7311           32.8    NaN
# 8812           35.2    NaN
# 8839           32.3    NaN
# 9273           22.6    NaN
# 10273          41.7    NaN
# 10488          28.4    NaN
# 10489          28.3    NaN
# 11013          28.6    NaN
# 11334          42.6    NaN
# 11459          36.7    NaN
# 11517          35.0    NaN
# 12319          39.7    NaN
# 12331          36.5    NaN
# 12436          36.4    NaN
# 13679          37.4    NaN
# 14063          22.3    NaN
# 14551          24.9    NaN
# 14901          43.7    NaN
# 14907          42.6    NaN

# %%
df_copy = df.copy()

# %%
df.loc[df['SCHOOL INDEX'] == 'U3859', 'SCHOOL'] = 'St. Gracious S.S LIRA'

# %%
# Get admissions by District
getAdmissionsByDistrict(df, 'iganga').sort_values(by='TOTAL WEIGHT', ascending=False)
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                     NAME  \
# 8404    23APF871087435114146        U0013  U0013/526  MIREMBE PRICEY SAMANTHA
# 14145   23APF366753009141449        U0061  U0061/551          MUTESI JAMILLAH
# 6947   23APF1103539225137561        U0124  U0124/560             SAJJABI ALEX
# 10248  23APF1420692019149215        U0017  U0017/560             MUGAYA MARIA
# 11317  23APF1193981484140507        U1698  U1698/501       TIKIBONEKA  MARIAM
# ...                      ...          ...        ...                      ...
# 909     23APF584897429150243        U0183  U0183/575         NANDHEGO REBECCA
# 9410   23APF1413249701119183        U0896  U0896/961            KWAGALA FAITH
# 2418     23APF54906142677348        U1602  U1602/526        TAMUZADE MUDASIRU
# 1640   23APF1351200345134434        U3738  U3738/537             MENYA FAHADI
# 9429   23APF1536445226130367        U0069  U0069/676        MUSAASIZI HILLARY
#
#       GENDER  UACE YEAR  CODE DISTRICT COURSE CODE  \
# 8404       F     2022.0  10.0   IGANGA         BSW
# 14145      F     2022.0  10.0   IGANGA         SQS
# 6947       M     2022.0  10.0   IGANGA         BPG
# 10248      F     2022.0  10.0   IGANGA         COM
# 11317      F     2022.0  10.0   IGANGA         EDA
# ...      ...        ...   ...      ...         ...
# 909        F     2022.0  10.0   IGANGA         ARS
# 9410       F     2022.0  10.0   IGANGA         BUS
# 2418       M     2016.0  10.0   IGANGA         BBA
# 1640       M     2022.0  10.0   IGANGA         BAX
# 9429       M     2022.0  10.0   IGANGA         BUS
#
#                                          COURSE NAME  TOTAL WEIGHT  \
# 8404                     B.SC.(Software Engineering)          48.5
# 14145                         BSC Quantity Surveying          47.6
# 6947       BSC (Petroleum Geoscience and Production)          47.2
# 10248                           Bachelor of Commerce          45.7
# 11317                Bachelor of Arts with Education          44.4
# ...                                              ...           ...
# 909                                        BA (Arts)          15.8
# 9410                           B.Business Statistics          15.2
# 2418       Bachelor of Business Administration (EVE)          14.5
# 1640   B. AGRICULTURAL & RURAL INNOVATION (EXTERNAL)          14.3
# 9429                           B.Business Statistics          13.8
#
#                                SCHOOL
# 8404               GAYAZA HIGH SCHOOL
# 14145         NABISUNSA GIRLS' SCHOOL
# 6947          BUDINI SECONDARY SCHOOL
# 10248         IGANGA SECONDARY SCHOOL
# 11317                             NaN
# ...                               ...
# 909    UGANDA MARTYRS'HIGH SC. RUBAGA
# 9410            ST.PETER'S SS, NAALYA
# 2418                              NaN
# 1640                              NaN
# 9429          KYAMBOGO COLLEGE SCHOOL
#
# [213 rows x 12 columns]

# %%
df[df['SCHOOL'].isna() == True]
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                     NAME  \
# 14      23APF231927019128941        U0960  U0960/506            LUUTU DOUGLAS
# 17     23APF1031507983139846        U3219  U3219/507         NANDAGIRE SCOVIA
# 32      23APF724414868141141        U3219  U3219/508            NAMBAYO KATHY
# 33     23APF1413319323135980        U1969  U1969/524          KAKOOZA MOHMMAD
# 38      23APF269087811114307        U3941  U3941/514  LUKYAMUZI JUDE THADDEUS
# ...                      ...          ...        ...                      ...
# 14884  23APF1135184133134407        U3374  U3374/528              OCHOM BRIAN
# 14886    23APF35679080123129        U0157  U0157/599         NYAKATO PRINCESS
# 14887   23APF717262298129715        U1988  U1988/501          ATWINE  SHEILLA
# 14888  23APF1422105617141114        U4099  U4099/513         KIWALABYE COLLIN
# 14892   23APF252772198131507        U2791  U2791/538      KWAGALA GIFT GLADYS
#
#       GENDER  UACE YEAR  CODE   DISTRICT COURSE CODE  \
# 14         M     2022.0  16.0    KAMPALA         ACC
# 17         F     2022.0  49.0      RAKAI         ACC
# 32         F     2022.0  77.0     BUDAKA         ACC
# 33         M     2022.0  88.0  BUTAMBALA         ACC
# 38         M     2022.0  33.0     MASAKA         ACC
# ...      ...        ...   ...        ...         ...
# 14884      M     2022.0  54.0     TORORO         TTM
# 14886      F     2022.0  46.0   NTUNGAMO         TTM
# 14887      F     2022.0  50.0  RUKUNGIRI         TTM
# 14888      M     2022.0  75.0    MITYANA         TTM
# 14892      F     2022.0  17.0     KAMULI         TTM
#
#                                  COURSE NAME  TOTAL WEIGHT SCHOOL
# 14                     BSC. Accounting (EVE)          35.8    NaN
# 17                     BSC. Accounting (EVE)          34.6    NaN
# 32                     BSC. Accounting (EVE)          31.3    NaN
# 33                     BSC. Accounting (EVE)          31.2    NaN
# 38                     BSC. Accounting (EVE)          31.0    NaN
# ...                                      ...           ...    ...
# 14884  B.Travel and Tourism Management (EVE)          18.5    NaN
# 14886  B.Travel and Tourism Management (EVE)          18.3    NaN
# 14887  B.Travel and Tourism Management (EVE)          18.3    NaN
# 14888  B.Travel and Tourism Management (EVE)          18.0    NaN
# 14892  B.Travel and Tourism Management (EVE)          17.4    NaN
#
# [1734 rows x 12 columns]

# %%
df.sort_values(by=['TOTAL WEIGHT'], ascending=False)
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                     NAME  \
# 14112   23APF876975068117846        U2789  U2789/828  ADONGO ELIZABETH OKELLO
# 4286   23APF1120677708142673        U0802  U0802/506        NANKABIRWA KEVINA
# 12438  23APF1381106049127095        U0060  U0060/517           KANGABE SHEILA
# 13455   23APF500143091107165        U0013  U0013/547            KYEYUNE SHIBA
# 13456   23APF340101816125698        U0077  U0077/589       CHEMUTAI PRODESHIA
# ...                      ...          ...        ...                      ...
# 5913     23APF91317904136028        U3654  U3654/501           SENOMBE BLASIO
# 10754  23APF1256764946119098        U0844  U0844/529   KIFAMPA RICHARD ARTHUR
# 9842   23APF1055656862136180        U0546  U0546/519           TANDEKA LIVING
# 10755   23APF531931686107506        U3888  U3888/586           KASOZI MICHAEL
# 5875    23APF280789164125073        U0125  U0125/595            IKILENG DENIS
#
#       GENDER  UACE YEAR  CODE   DISTRICT COURSE CODE  \
# 14112      F     2022.0  31.0       LIRA         SOW
# 4286       F     2022.0  33.0     MASAKA         BEN
# 12438      F     2022.0  26.0     KISORO         IST
# 13455      F     2022.0  42.0     MUKONO         PSM
# 13456      F     2022.0  20.0  KAPCHORWA         PSM
# ...      ...        ...   ...        ...         ...
# 5913       M     2022.0  55.0     WAKISO         BJO
# 10754      M     2022.0  16.0    KAMPALA         COX
# 9842       M     2020.0  72.0   KIRUHURA         CMM
# 10755      M     2022.0  85.0     BUIKWE         COX
# 5875       M     2014.0  54.0     TORORO         BJJ
#
#                                   COURSE NAME  TOTAL WEIGHT  \
# 14112                 BACHELOR OF SOCIAL WORK          53.9
# 4286             Bachelor of Entrepreneurship          53.6
# 12438     B. INFORMATION SYSTEMS & TECHNOLOGY          53.6
# 13455     B. Procurement and Supply Chain Mgt          53.6
# 13456     B. Procurement and Supply Chain Mgt          53.5
# ...                                       ...           ...
# 5913                 B. COMMERCE, JINJA (DAY)           9.7
# 10754                        B.Commerce (EXT)           9.7
# 9842                          B.Commerce(MBR)           9.1
# 10755                        B.Commerce (EXT)           8.9
# 5875   BACHELOR OF COMMERCE (MUBS JINJA) EVE.           8.9
#
#                              SCHOOL
# 14112  MENGO SECONDARY SCHOOL ANNEX
# 4286      MAKINDYE SECONDARY SCHOOL
# 12438     TRINITY COLLEGE, NABBINGO
# 13455            GAYAZA HIGH SCHOOL
# 13456        GOMBE SECONDARY SCHOOL
# ...                             ...
# 5913                            NaN
# 10754        MULUSA ACADEMY, LUWERO
# 9842              KAARO HIGH SCHOOL
# 10755                           NaN
# 5875       PALLISA SECONDARY SCHOOL
#
# [14915 rows x 12 columns]

# %%
# Bining Students' total weight
TotalWeights = df['TOTAL WEIGHT']
# bins
bins = [0, 10, 20, 30, 40, 50, 54]

# %%
ranges = pd.cut(TotalWeights, bins,
               labels=["Very Low", "Low", "Average", "Good", "Very Good", "Exceptional"])

# %%
ranges
# Out:
# 0        Very Good
# 1        Very Good
# 2        Very Good
# 3             Good
# 4             Good
#            ...
# 14910    Very Good
# 14911    Very Good
# 14912    Very Good
# 14913    Very Good
# 14914    Very Good
# Name: TOTAL WEIGHT, Length: 14915, dtype: category
# Categories (6, object): ['Very Low' < 'Low' < 'Average' < 'Good' < 'Very Good' < 'Exceptional']

# %%
ranges = ranges.tolist()

# %%
len(ranges)
# Out:
# 14915

# %%
print(len(df))
# Out:
# 14915

# %%
df.insert(11, "WEIGHT RANGE", ranges)

# %%
df[df['WEIGHT RANGE'] == 'Exceptional'].sort_values(by=['TOTAL WEIGHT'], ascending=False)
# 14118            MAGUMBA TIMOTHY      M     2022.0   35.0        MAYUGE
# 913           SSEGIRINNYA COSMAS      M     2015.0   55.0        WAKISO
# 12837            KASAGGA ASHIRAF      M     2022.0   16.0       KAMPALA
# 12441            WATAKA EMMANUEL      M     2022.0   73.0        KOBOKO
# 12289               MUYUNGA ERIC      M     2022.0   49.0         RAKAI
# 179             NAHURIRA PHIONAH      F     2022.0   51.0     SEMBABULE
# 5085             GENO ISAAC ODOI      M     2022.0   16.0       KAMPALA
#
#       COURSE CODE                                    COURSE NAME  \
# 14112         SOW                        BACHELOR OF SOCIAL WORK
# 4286          BEN                   Bachelor of Entrepreneurship
# 13455         PSM            B. Procurement and Supply Chain Mgt
# 12438         IST            B. INFORMATION SYSTEMS & TECHNOLOGY
# 13456         PSM            B. Procurement and Supply Chain Mgt
# 9781          CIA                       BSC.(Civil Engineering)A
# 10058         COE                           Bachelor of Commerce
# 9782          CIA                       BSC.(Civil Engineering)A
# 12439         IST            B. INFORMATION SYSTEMS & TECHNOLOGY
# 10799         CSC                        B.SC.(Computer Science)
# 10245         COM                           Bachelor of Commerce
# 8398          BSW                    B.SC.(Software Engineering)
# 7132          BQE              Bachelor (Quantitative Economics)
# 10059         COE                           Bachelor of Commerce
# 13457         PSM            B. Procurement and Supply Chain Mgt
# 10060         COE                           Bachelor of Commerce
# 12440         IST            B. INFORMATION SYSTEMS & TECHNOLOGY
# 13459         PSM            B. Procurement and Supply Chain Mgt
# 13458         PSM            B. Procurement and Supply Chain Mgt
# 11275         EDA                Bachelor of Arts with Education
# 666           ARC                                 B.Architecture
# 14113         SOW                        BACHELOR OF SOCIAL WORK
# 14114         SOW                        BACHELOR OF SOCIAL WORK
# 13175         PSC       B.Procurement and Supply Chain Mgt (EVE)
# 2425          BBC                         B. Bussiness Computing
# 13177         PSC       B.Procurement and Supply Chain Mgt (EVE)
# 13176         PSC       B.Procurement and Supply Chain Mgt (EVE)
# 3700          BBI  Bachelor of Science in Biomedical Engineering
# 13460         PSM            B. Procurement and Supply Chain Mgt
# 14115         SOW                        BACHELOR OF SOCIAL WORK
# 10061         COE                           Bachelor of Commerce
# 13461         PSM            B. Procurement and Supply Chain Mgt
# 6941          BPG      BSC (Petroleum Geoscience and Production)
# 9783          CIA                       BSC.(Civil Engineering)A
# 12287         ELE                   BSC (Electrical Engineering)
# 11276         EDA                Bachelor of Arts with Education
# 12288         ELE                   BSC (Electrical Engineering)
# 14116         SOW                        BACHELOR OF SOCIAL WORK
# 10800         CSC                        B.SC.(Computer Science)
# 6942          BPG      BSC (Petroleum Geoscience and Production)
# 10877         CSE                    BSC.(Computer Science)(EVE)
# 178           ADM            Bachelor of Business Administration
# 10878         CSE                    BSC.(Computer Science)(EVE)
# 667           ARC                                 B.Architecture
# 5084          BIB                      B. International Business
# 14117         SOW                        BACHELOR OF SOCIAL WORK
# 14118         SOW                        BACHELOR OF SOCIAL WORK
# 913           ASE                       BA(Social Sciences)(EVE)
# 10878          50.4  Exceptional     CORNERSTONE LEADERSHIP ACADEMY
# 667            50.4  Exceptional           SEETA HIGH SCHOOL-MUKONO
# 5084           50.3  Exceptional                  SEETA HIGH SCHOOL
# 14117          50.3  Exceptional            NDEJJE SECONDARY SCHOOL
# 14118          50.3  Exceptional            BUDINI SECONDARY SCHOOL
# 913            50.2  Exceptional          ST.AUGUSTINE COL., WAKISO
# 12837          50.1  Exceptional  BILAL ISLAMIC SEC. SCHOOL, BWAISE
# 12441          50.1  Exceptional         ST HENRY'S COLLEGE, KITOVU
# 12289          50.1  Exceptional          ST.MARY'S COLLEGE, LUGAZI
# 179            50.1  Exceptional               BULOBA ROYAL COLLEGE
# 5085           50.1  Exceptional        NAALYA SEC. SCHOOL ,KAMPALA

# %%
df['WEIGHT RANGE'].unique()
# Out:
# array(['Very Good', 'Good', 'Average', 'Low', 'Exceptional', 'Very Low'],
#       dtype=object)

# %%
colWT = df['TOTAL WEIGHT']

# %%
# Sampling dataframe
# This can be used to select a random student and track her performance over time.
sampler = np.random.permutation(1000)
df.take(sampler).head()
# Out:
#             APPLICATION NO SCHOOL INDEX   INDEX NO                NAME GENDER  \
# 517   23APF331366071132279        U0781  U0781/580     NAMAGANDA NORAH      F
# 211   23APF538973411108338        U2338  U2338/635   KUSEMERERWA JONES      M
# 160   23APF254085235124676        U0174  U0174/559    SSEMPIJJA REAGAN      M
# 587  23APF1290889842124486        U2338  U2338/773  SSEWANKAMBO DANIEL      M
# 643  23APF1009331309115789        U2236  U2236/538    CHEPTOEK OBADIAH      M
#
#      UACE YEAR  CODE  DISTRICT COURSE CODE  \
# 517     2022.0  81.0  NAKASEKE         AGE
# 211     2022.0  13.0  KABAROLE         ADM
# 160     2022.0  85.0    BUIKWE         ADJ
# 587     2022.0  55.0    WAKISO         AGM
# 643     2022.0  96.0     KWEEN         AGR
#
#                              COURSE NAME  TOTAL WEIGHT WEIGHT RANGE  \
# 517         BSC Agricultural Engineering          45.1    Very Good
# 211  Bachelor of Business Administration          43.1    Very Good
# 160     B.Business Administration(Jinja)          27.6      Average
# 587  Bachelor of Agribusiness Management          36.1         Good
# 643                      BSC Agriculture          35.3         Good
#
#                            SCHOOL
# 517     ST.AUGUSTINE COL., WAKISO
# 211  ST.MARY'S SS KITENDE (ANNEX)
# 160        MEHTA SECONDARY SCHOOL
# 587  ST.MARY'S SS KITENDE (ANNEX)
# 643     ST.MARY'S COLLEGE, LUGAZI

# %%
df.iloc[sampler]
# Out:
#             APPLICATION NO SCHOOL INDEX   INDEX NO                NAME GENDER  \
# 517   23APF331366071132279        U0781  U0781/580     NAMAGANDA NORAH      F
# 211   23APF538973411108338        U2338  U2338/635   KUSEMERERWA JONES      M
# 160   23APF254085235124676        U0174  U0174/559    SSEMPIJJA REAGAN      M
# 587  23APF1290889842124486        U2338  U2338/773  SSEWANKAMBO DANIEL      M
# 643  23APF1009331309115789        U2236  U2236/538    CHEPTOEK OBADIAH      M
# ..                     ...          ...        ...                 ...    ...
# 8     23APF515017899120808        U1609  U1609/550      KIZITO PATRICK      M
# 323    23APF17154100107843        U0009  U0009/546   MIREMBE ELIZABETH      F
# 571   23APF317121781150601        U0801  U0801/642   TAMALE GRACE ERIC      M
# 163  23APF1316852623122726        U0025  U0025/711    ASHITU MUSTAPHER      F
# 191  23APF1390733042149984        U0859  U0859/518        WAMBUI MERCY      F
#
#      UACE YEAR   CODE  DISTRICT COURSE CODE  \
# 517     2022.0   81.0  NAKASEKE         AGE
# 211     2022.0   13.0  KABAROLE         ADM
# 160     2022.0   85.0    BUIKWE         ADJ
# 587     2022.0   55.0    WAKISO         AGM
# 643     2022.0   96.0     KWEEN         AGR
# ..         ...    ...       ...         ...
# 8       2011.0   16.0   KAMPALA         ACC
# 323     2022.0    6.0  BUSHENYI         ADM
# 571     2022.0  120.0   KYOTERA         AGM
# 163     2022.0    4.0    BUGIRI         ADJ
# 191     2022.0   75.0   MITYANA         ADM
#
#                              COURSE NAME  TOTAL WEIGHT WEIGHT RANGE  \
# 517         BSC Agricultural Engineering          45.1    Very Good
# 211  Bachelor of Business Administration          43.1    Very Good
# 160     B.Business Administration(Jinja)          27.6      Average
# 587  Bachelor of Agribusiness Management          36.1         Good
# 643                      BSC Agriculture          35.3         Good
# ..                                   ...           ...          ...
# 8                  BSC. Accounting (EVE)          37.9         Good
# 323  Bachelor of Business Administration          38.7         Good
# 571  Bachelor of Agribusiness Management          38.0         Good
# 163     B.Business Administration(Jinja)          25.4      Average
# 191  Bachelor of Business Administration          44.6    Very Good
#
#                            SCHOOL
# 517     ST.AUGUSTINE COL., WAKISO
# 211  ST.MARY'S SS KITENDE (ANNEX)
# 160        MEHTA SECONDARY SCHOOL
# 587  ST.MARY'S SS KITENDE (ANNEX)
# 643     ST.MARY'S COLLEGE, LUGAZI
# ..                            ...
# 8                      NAALYA SSS
# 323     BWERANYANGI GIRLS' SCHOOL
# 571   NAALYA SEC. SCHOOL ,KAMPALA
# 163       KIBULI SECONDARY SCHOOL
# 191      CENTRAL COLLEGE, MITYANA
#
# [1000 rows x 13 columns]

# %%
# use sample
df.sample(n=1,
    # frac=0.00005,
          replace=False,
         )
# Out:
#               APPLICATION NO SCHOOL INDEX   INDEX NO                    NAME  \
# 14881  23APF1522958472146394        U2257  U2257/509  SSEBYALA PETER ROGGERS
#
#       GENDER  UACE YEAR  CODE DISTRICT COURSE CODE  \
# 14881      M     2022.0  91.0    GOMBA         TTM
#
#                                  COURSE NAME  TOTAL WEIGHT WEIGHT RANGE SCHOOL
# 14881  B.Travel and Tourism Management (EVE)          18.8          Low    NaN

# %% [markdown]
# <h3>Descriptive Statistics</h3>

# %%
results = df['TOTAL WEIGHT'].groupby(df['WEIGHT RANGE'], observed=True).agg(['count', 'min', 'max', 'mean'])

# %%
results
# Out:
#               count   min   max       mean
# WEIGHT RANGE
# Average        5490  20.1  30.0  25.618852
# Exceptional      53  50.1  53.9  51.366038
# Good           5983  30.1  40.0  34.654906
# Low            1132  10.2  20.0  17.628357
# Very Good      2252  40.1  50.0  43.357682
# Very Low          5   8.9   9.7   9.260000

# %%
# Programs
programs = df['TOTAL WEIGHT'].groupby(df['COURSE NAME'], observed=True).agg(['count', 'mean', 'min', 'max']).sort_values(by='mean', ascending=False)

# %%
programs.head()['count']
# Out:
# COURSE NAME
# B.Architecture                                 4
# BSC.(Civil Engineering)A                      11
# BACHELOR OF SOCIAL WORK                       18
# BSC (Electrical Engineering)                  24
# Bachelor of Medicine & Bachelor of Surgery    18
# Name: count, dtype: int64

# %%
# Reindexing by Program
df[df['NAME'] == 'LUKABWE DOUGLAS MARK']
# Out:
#          APPLICATION NO SCHOOL INDEX   INDEX NO                  NAME GENDER  \
# 0  23APF412304454141015        U0391  U0391/673  LUKABWE DOUGLAS MARK      M
#
#    UACE YEAR  CODE DISTRICT COURSE CODE            COURSE NAME  TOTAL WEIGHT  \
# 0     2022.0  42.0   MUKONO         ACC  BSC. Accounting (EVE)          42.2
#
#   WEIGHT RANGE                      SCHOOL
# 0    Very Good  ST.JOSEPH'S S S, NAGGALAMA

# %%
# Pivoting on Application number

# %%
# Average weight per course
AvgProgramWeight = df.groupby("COURSE CODE")['TOTAL WEIGHT'].mean()

# %% [markdown]
# <h1>Visualization</h1>
# <p>Objectives for data visualization</p>
# <ul>
#     <li>Graphical representation of statistics</li>
#     <li>Identify outliers, patterns, trends in the complex and large dataset</li>
#     <li>Achieve Interactive data exploration</li>
#     <li>Construct an compelling storyline</li>
#     <li>Improve accessiblity to data analytics</li>
# </ul>

# %%
weights = df['TOTAL WEIGHT'].sort_values(ascending=True)

# %%
import matplotlib.pyplot as plt
# fig = plt.figure()
# ax1 = fig.add_subplot(2, 2, 1)
# ax2 = fig.add_subplot(2, 2, 2)
# ax3 = fig.add_subplot(2, 2, 3)
plt.hist(weights,
         # color="black",
         linestyle="dashed"
       );

# %%
# Admissions per program count
df['COURSE CODE'].value_counts().head().plot.bar(
    figsize=(5,5),
    rot=0,
    # xlim=[0, 500],
);

# %%
# Plot by Weight Range
rangeCounts = df['WEIGHT RANGE'].value_counts()
rangeCounts.plot.barh(
    figsize=(5, 5),
);

# %%
df[df['TOTAL WEIGHT'] >= 50]['COURSE CODE'].value_counts().plot.barh();

# %%
# lineplots are not suitable for variable comparions.
# They are best for trend analysis over a period of time.
fig, ax = plt.subplots()
ax.plot(rangeCounts,
       );

# %%
# Plot program statistics
# Plot by college programs
# Program admission counts
df['COURSE CODE'].value_counts()
# programs.head().plot.bar(),
# Out:
# COURSE CODE
# EDA    836
# BBA    783
# BBD    633
# BIB    490
# COM    392
#       ...
# BUE      3
# BMR      3
# DPA      3
# BDT      3
# HMA      3
# Name: count, Length: 154, dtype: int64

# %%
# Weight distribution
df['TOTAL WEIGHT'].plot.hist(bins=50,
                            );

# %%
# kde plot
df['TOTAL WEIGHT'].plot.density(
);

# %%
# pairplot
# These plots are to be intepreted with text or simpler plots
sns.pairplot(df,
             diag_kind='kde',
             plot_kws={"alpha": 0.2},
            );
