# %%
import numpy as np
import pandas as pd

# %%
frame = pd.read_csv("../Data/Private.csv",
           index_col=0)

# %%
frame
# Out:
#                         INDEX NO                   NAME GENDER  UACE YEAR  \
# APPLICATION NO
# 23APF412304454141015   U0391/673   LUKABWE DOUGLAS MARK      M     2022.0
# 23APF345674424112360   U1249/532             LULE ISAAC      M     2022.0
# 23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F     2022.0
# 23APF519647933132646   U1611/887       NAMBALYE EVELYNE      F     2022.0
# 23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F     2022.0
# ...                          ...                    ...    ...        ...
# 23APF727648568141557   U0017/548  KIZZA VANESSA ITRONCE      F     2022.0
# 23APF963075058135059   U0033/581            OTIM DANIEL      M     2022.0
# 23APF1618205309130850  U0077/736          MUKETI  JOVIA      F     2022.0
# 23APF575513287117711   U0077/564           AWOR REBECCA      F     2022.0
# 23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F     2022.0
#
#                        CODE DISTRICT COURSE CODE             COURSE NAME  \
# APPLICATION NO
# 23APF412304454141015   42.0   MUKONO         ACC   BSC. Accounting (EVE)
# 23APF345674424112360   40.0    MPIGI         ACC   BSC. Accounting (EVE)
# 23APF1361730063122187  21.0   KASESE         ACC   BSC. Accounting (EVE)
# 23APF519647933132646   33.0   MASAKA         ACC   BSC. Accounting (EVE)
# 23APF1481620160129238  65.0   IBANDA         ACC   BSC. Accounting (EVE)
# ...                     ...      ...         ...                     ...
# 23APF727648568141557   17.0   KAMULI         VET  B. Veterinary Medicine
# 23APF963075058135059   31.0     LIRA         VET  B. Veterinary Medicine
# 23APF1618205309130850  74.0  MARACHA         VET  B. Veterinary Medicine
# 23APF575513287117711   31.0     LIRA         VET  B. Veterinary Medicine
# 23APF1477867021106233  48.0  PALLISA         VET  B. Veterinary Medicine
#
#                        TOTAL WEIGHT
# APPLICATION NO
# 23APF412304454141015           42.2
# 23APF345674424112360           41.1
# 23APF1361730063122187          40.6
# 23APF519647933132646           38.8
# 23APF1481620160129238          38.4
# ...                             ...
# 23APF727648568141557           41.8
# 23APF963075058135059           41.7
# 23APF1618205309130850          41.6
# 23APF575513287117711           40.4
# 23APF1477867021106233          40.1
#
# [14915 rows x 9 columns]

# %%
frame.dropna(how="any")
# Out:
#                    Form ID   Index No                   NAME GENDER  \
# 0     23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1     23APF345674424112360  U1249/532             LULE ISAAC      M
# 2    23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3     23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4    23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ..                     ...        ...                    ...    ...
# 222  23APF1674647943113045  U2789/769          MAFABI  EDGAR      M
# 223  23APF1553004744147784  U0009/541     KEMIGISHA SHANITAH      F
# 224  23APF1425422752115622  U4144/507      NAKITANDWE SHARON      F
# 225  23APF1269085013144231  U0060/511  BAGAYA SHELDYNE WINYI      F
# 226   23APF192601537128082  U0083/547         CYNTHIA PRAISE      F
#
#      UACE YEAR  CODE  DISTRICT COURSE CODE  \
# 0       2022.0  42.0    MUKONO         ACC
# 1       2022.0  40.0     MPIGI         ACC
# 2       2022.0  21.0    KASESE         ACC
# 3       2022.0  33.0    MASAKA         ACC
# 4       2022.0  65.0    IBANDA         ACC
# ..         ...   ...       ...         ...
# 222     2022.0  52.0   SIRONKO         ADM
# 223     2022.0   6.0  BUSHENYI         ADM
# 224     2022.0  71.0    KALIRO         ADM
# 225     2022.0   9.0     HOIMA         ADM
# 226     2022.0  21.0    KASESE         ADM
#
#                              COURSE NAME  Total Weight
# 0                  BSC. Accounting (EVE)          42.2
# 1                  BSC. Accounting (EVE)          41.1
# 2                  BSC. Accounting (EVE)          40.6
# 3                  BSC. Accounting (EVE)          38.8
# 4                  BSC. Accounting (EVE)          38.4
# ..                                   ...           ...
# 222  Bachelor of Business Administration          42.7
# 223  Bachelor of Business Administration          42.6
# 224  Bachelor of Business Administration          42.6
# 225  Bachelor of Business Administration          42.6
# 226  Bachelor of Business Administration          42.6
#
# [223 rows x 10 columns]

# %%
frame
# Out:
#                    Form ID   Index No                   NAME GENDER  \
# 0     23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1     23APF345674424112360  U1249/532             LULE ISAAC      M
# 2    23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3     23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4    23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ..                     ...        ...                    ...    ...
# 222  23APF1674647943113045  U2789/769          MAFABI  EDGAR      M
# 223  23APF1553004744147784  U0009/541     KEMIGISHA SHANITAH      F
# 224  23APF1425422752115622  U4144/507      NAKITANDWE SHARON      F
# 225  23APF1269085013144231  U0060/511  BAGAYA SHELDYNE WINYI      F
# 226   23APF192601537128082  U0083/547         CYNTHIA PRAISE      F
#
#      UACE YEAR  CODE  DISTRICT COURSE CODE  \
# 0       2022.0  42.0    MUKONO         ACC
# 1       2022.0  40.0     MPIGI         ACC
# 2       2022.0  21.0    KASESE         ACC
# 3       2022.0  33.0    MASAKA         ACC
# 4       2022.0  65.0    IBANDA         ACC
# ..         ...   ...       ...         ...
# 222     2022.0  52.0   SIRONKO         ADM
# 223     2022.0   6.0  BUSHENYI         ADM
# 224     2022.0  71.0    KALIRO         ADM
# 225     2022.0   9.0     HOIMA         ADM
# 226     2022.0  21.0    KASESE         ADM
#
#                              COURSE NAME  Total Weight
# 0                  BSC. Accounting (EVE)          42.2
# 1                  BSC. Accounting (EVE)          41.1
# 2                  BSC. Accounting (EVE)          40.6
# 3                  BSC. Accounting (EVE)          38.8
# 4                  BSC. Accounting (EVE)          38.4
# ..                                   ...           ...
# 222  Bachelor of Business Administration          42.7
# 223  Bachelor of Business Administration          42.6
# 224  Bachelor of Business Administration          42.6
# 225  Bachelor of Business Administration          42.6
# 226  Bachelor of Business Administration          42.6
#
# [226 rows x 10 columns]

# %%
frame = frame.astype({"UACE YEAR": "int64",
             "CODE": "int64",
             })

# %%
frame
# Out:
#                         INDEX NO                   NAME GENDER  UACE YEAR  \
# APPLICATION NO
# 23APF412304454141015   U0391/673   LUKABWE DOUGLAS MARK      M       2022
# 23APF345674424112360   U1249/532             LULE ISAAC      M       2022
# 23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F       2022
# 23APF519647933132646   U1611/887       NAMBALYE EVELYNE      F       2022
# 23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F       2022
# ...                          ...                    ...    ...        ...
# 23APF727648568141557   U0017/548  KIZZA VANESSA ITRONCE      F       2022
# 23APF963075058135059   U0033/581            OTIM DANIEL      M       2022
# 23APF1618205309130850  U0077/736          MUKETI  JOVIA      F       2022
# 23APF575513287117711   U0077/564           AWOR REBECCA      F       2022
# 23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F       2022
#
#                        CODE DISTRICT COURSE CODE             COURSE NAME  \
# APPLICATION NO
# 23APF412304454141015     42   MUKONO         ACC   BSC. Accounting (EVE)
# 23APF345674424112360     40    MPIGI         ACC   BSC. Accounting (EVE)
# 23APF1361730063122187    21   KASESE         ACC   BSC. Accounting (EVE)
# 23APF519647933132646     33   MASAKA         ACC   BSC. Accounting (EVE)
# 23APF1481620160129238    65   IBANDA         ACC   BSC. Accounting (EVE)
# ...                     ...      ...         ...                     ...
# 23APF727648568141557     17   KAMULI         VET  B. Veterinary Medicine
# 23APF963075058135059     31     LIRA         VET  B. Veterinary Medicine
# 23APF1618205309130850    74  MARACHA         VET  B. Veterinary Medicine
# 23APF575513287117711     31     LIRA         VET  B. Veterinary Medicine
# 23APF1477867021106233    48  PALLISA         VET  B. Veterinary Medicine
#
#                        TOTAL WEIGHT
# APPLICATION NO
# 23APF412304454141015           42.2
# 23APF345674424112360           41.1
# 23APF1361730063122187          40.6
# 23APF519647933132646           38.8
# 23APF1481620160129238          38.4
# ...                             ...
# 23APF727648568141557           41.8
# 23APF963075058135059           41.7
# 23APF1618205309130850          41.6
# 23APF575513287117711           40.4
# 23APF1477867021106233          40.1
#
# [14915 rows x 9 columns]

# %%
frame.dtypes
# Out:
# INDEX NO         object
# NAME             object
# GENDER           object
# UACE YEAR         int64
# CODE              int64
# DISTRICT         object
# COURSE CODE      object
# COURSE NAME      object
# TOTAL WEIGHT    float64
# dtype: object

# %%
frame.groupby(["UACE YEAR", "DISTRICT"])["NAME"].count()
# Out:
# UACE YEAR  DISTRICT
# 1995       BUSIA          1
#            MUKONO         1
# 1996       LUUKA          1
#            MPIGI          1
#            SHEEMA         1
#                        ...
# 2022       SOROTI       116
#            TORORO       232
#            WAKISO      1460
#            YUMBE         18
#            ZOMBO         25
# Name: NAME, Length: 651, dtype: int64
