# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
frame = pd.read_csv("../Data/Private.csv",
           # index_col=0,
                   )

# %%
frame
# Out:
#               APPLICATION NO   INDEX NO                   NAME GENDER  \
# 0       23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1       23APF345674424112360  U1249/532             LULE ISAAC      M
# 2      23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3       23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4      23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ...                      ...        ...                    ...    ...
# 14910   23APF727648568141557  U0017/548  KIZZA VANESSA ITRONCE      F
# 14911   23APF963075058135059  U0033/581            OTIM DANIEL      M
# 14912  23APF1618205309130850  U0077/736          MUKETI  JOVIA      F
# 14913   23APF575513287117711  U0077/564           AWOR REBECCA      F
# 14914  23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F
#
#        UACE YEAR  CODE DISTRICT COURSE CODE             COURSE NAME  \
# ...

# %%
frame.dropna(how="any")
# Out:
#               APPLICATION NO   INDEX NO                   NAME GENDER  \
# 0       23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1       23APF345674424112360  U1249/532             LULE ISAAC      M
# 2      23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3       23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4      23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ...                      ...        ...                    ...    ...
# 14910   23APF727648568141557  U0017/548  KIZZA VANESSA ITRONCE      F
# 14911   23APF963075058135059  U0033/581            OTIM DANIEL      M
# 14912  23APF1618205309130850  U0077/736          MUKETI  JOVIA      F
# 14913   23APF575513287117711  U0077/564           AWOR REBECCA      F
# 14914  23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F
#
#        UACE YEAR  CODE DISTRICT COURSE CODE             COURSE NAME  \
# ...

# %%
frame
# Out:
#               APPLICATION NO   INDEX NO                   NAME GENDER  \
# 0       23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1       23APF345674424112360  U1249/532             LULE ISAAC      M
# 2      23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3       23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4      23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ...                      ...        ...                    ...    ...
# 14910   23APF727648568141557  U0017/548  KIZZA VANESSA ITRONCE      F
# 14911   23APF963075058135059  U0033/581            OTIM DANIEL      M
# 14912  23APF1618205309130850  U0077/736          MUKETI  JOVIA      F
# 14913   23APF575513287117711  U0077/564           AWOR REBECCA      F
# 14914  23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F
#
#        UACE YEAR  CODE DISTRICT COURSE CODE             COURSE NAME  \
# ...

# %%
frame = frame.astype({"UACE YEAR": "int64",
             "CODE": "int64",
             })

# %%
frame
# Out:
#               APPLICATION NO   INDEX NO                   NAME GENDER  \
# 0       23APF412304454141015  U0391/673   LUKABWE DOUGLAS MARK      M
# 1       23APF345674424112360  U1249/532             LULE ISAAC      M
# 2      23APF1361730063122187  U0459/676    HAULAH SULAIT BIIRA      F
# 3       23APF519647933132646  U1611/887       NAMBALYE EVELYNE      F
# 4      23APF1481620160129238  U0083/555        KEMIGISHA RUSIA      F
# ...                      ...        ...                    ...    ...
# 14910   23APF727648568141557  U0017/548  KIZZA VANESSA ITRONCE      F
# 14911   23APF963075058135059  U0033/581            OTIM DANIEL      M
# 14912  23APF1618205309130850  U0077/736          MUKETI  JOVIA      F
# 14913   23APF575513287117711  U0077/564           AWOR REBECCA      F
# 14914  23APF1477867021106233  U0017/606  SAGATI LETICIA OKURUT      F
#
#        UACE YEAR  CODE DISTRICT COURSE CODE             COURSE NAME  \
# ...

# %%
frame.dtypes
# Out:
# APPLICATION NO     object
# INDEX NO           object
# NAME               object
# GENDER             object
# UACE YEAR           int64
# CODE                int64
# DISTRICT           object
# COURSE CODE        object
# COURSE NAME        object
# TOTAL WEIGHT      float64
# dtype: object

# %%
plt.figure(figsize=(30,30));
frame.groupby(["UACE YEAR"])["INDEX NO"].count(   
).head(20).plot(
    kind="bar",
    rot='vertical',
    title="Students admitted by Year",
    x="Year",
    y="Students",
);
plt.savefig("studentsAdmitted1995-2016.png");

# %%
plt.figure(figsize=(30,30));
frame.groupby(["UACE YEAR"])["INDEX NO"].count(   
).tail(7).plot(
    kind="bar",
    rot='vertical',
    title="Students admitted by Year",
    x="Year",
    y="Students",
);
plt.savefig("studentsAdmitted2016-2023.png");
